# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r'C:\Users\RIya\Desktop\6month-Data-Science\machine learning\medical\medical_project\data\medical_disease_prediction_10000.csv')

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
print(df.duplicated().sum())
print(df.isnull().sum())
# x=df.drop('Disease',axis=1)
# y=df[['Disease']]
# Out:
# 0
# Age                 0
# Gender              0
# BMI                 0
# BloodPressure       0
# GlucoseLevel        0
# Cholesterol         0
# HeartRate           0
# Smoking             0
# Alcohol             0
# PhysicalActivity    0
# FamilyHistory       0
# Disease             0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
gender_dict ={'Male':0, 'Female':1}
df['Gender'] = df['Gender'].map(gender_dict)

# %%
df['Gender'].unique()
# Out:
# array([0, 1])

# %%
df['Smoking'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
smoking_dict ={'Yes':1, 'No':0}
df['Smoking'] = df['Smoking'].map(smoking_dict)

# %%
df['Smoking'].unique()
# Out:
# array([0, 1])

# %%
df['Alcohol'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
alcohol_dict ={'Yes':1, 'No':0}
df['Alcohol'] = df['Alcohol'].map(alcohol_dict)

# %%
df['Alcohol'].unique()
# Out:
# array([0, 1])

# %%
df['PhysicalActivity'].unique()
# Out:
# <StringArray>
# ['Medium', 'High', 'Low']
# Length: 3, dtype: str

# %%
physical_dict={'Medium': 1, 'High': 2, 'Low': 0}
df['PhysicalActivity'] = df['PhysicalActivity'].map(physical_dict)

# %%
df['PhysicalActivity'].unique()
# Out:
# array([1, 2, 0])

# %%
df['FamilyHistory'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
family_dict ={'Yes':1, 'No':0}
df['FamilyHistory'] = df['FamilyHistory'].map(family_dict)

# %%
df['FamilyHistory'].unique()
# Out:
# array([0, 1])

# %%
df['Disease'].unique()
# Out:
# <StringArray>
# ['Healthy', 'Pre-Diabetes', 'Hypertension', 'Heart Disease', 'Diabetes']
# Length: 5, dtype: str

# %%
disease_dict ={'Healthy':1, 'Pre-Diabetes':2, 'Hypertension':3, 'Heart Disease':4, 'Diabetes':5}
df['Disease']=df['Disease'].map(disease_dict)

# %%
df['Disease'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       0  17.5            102           177          161         88
# 1      69       0  31.1            118           256          147         92
# 2      61       1  31.3            114           206          193         74
# 3      47       1  23.9            105           162          253         68
# 4      47       0  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       0  27.1            177           183          268         59
# 9996   84       0  29.2            142           215          145         77
# 9997   41       0  22.8            177           265          133         71
# 9998   55       0  29.0            126           241          298         57
# 9999   59       0  32.2            151           162          225         93
#
# ...

# %%
x=df.drop('Disease',axis=1)
y=df[['Disease']]

# %%
x
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       0  17.5            102           177          161         88
# 1      69       0  31.1            118           256          147         92
# 2      61       1  31.3            114           206          193         74
# 3      47       1  23.9            105           162          253         68
# 4      47       0  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       0  27.1            177           183          268         59
# 9996   84       0  29.2            142           215          145         77
# 9997   41       0  22.8            177           265          133         71
# 9998   55       0  29.0            126           241          298         57
# 9999   59       0  32.2            151           162          225         93
#
# ...

# %%
y
# Out:
#       Disease
# 0           1
# 1           2
# 2           1
# 3           1
# 4           1
# ...       ...
# 9995        3
# 9996        3
# 9997        3
# 9998        2
# 9999        2
#
# [10000 rows x 1 columns]

# %%
df.to_csv('cleaned_medical_disease_prediction.csv')
